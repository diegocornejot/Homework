# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
green_tripdata_2019=pd.read_csv('green_tripdata_2019-01.csv')

# %%
green_tripdata_2019.lpep_pickup_datetime=pd.to_datetime(green_tripdata_2019.lpep_pickup_datetime)
green_tripdata_2019.lpep_dropoff_datetime=pd.to_datetime(green_tripdata_2019.lpep_dropoff_datetime)

# %%
taxi_zone_lookup=pd.read_csv('taxi+_zone_lookup.csv')

# %%
green_tripdata_2019['diferencia']=green_tripdata_2019.lpep_dropoff_datetime-green_tripdata_2019.lpep_pickup_datetime

# %%
green_tripdata_2019.sort_values(by='diferencia')[['lpep_dropoff_datetime','lpep_pickup_datetime','diferencia']].to_excel('borrar.xlsx')

# %%
taxi_zone_lookup.sort_values('Zone')
# Out:
#      LocationID        Borough                     Zone service_zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# 5             6  Staten Island  Arrochar/Fort Wadsworth    Boro Zone
# 6             7         Queens                  Astoria    Boro Zone
# ..          ...            ...                      ...          ...
# 259         260         Queens                 Woodside    Boro Zone
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
taxi_zone_lookup[taxi_zone_lookup['LocationID']==146]
# Out:
#      LocationID Borough                           Zone service_zone
# 145         146  Queens  Long Island City/Queens Plaza    Boro Zone

# %%
green_tripdata_2019[green_tripdata_2019['PULocationID']==7][['RatecodeID','DOLocationID','tip_amount']].sort_values('tip_amount')
# Out:
#         RatecodeID  DOLocationID  tip_amount
# 393719           1           193       -0.66
# 23               1             7        0.00
# 371484           1           193        0.00
# 371443           1           129        0.00
# 371394           1           223        0.00
# ...            ...           ...         ...
# 15617            4           265       19.16
# 325386           1           265       25.00
# 403375           1           130       25.00
# 468169           1            43       30.00
# 506162           1           146       88.00
#
# [26046 rows x 3 columns]

# %%
green_tripdata_2019_enero=green_tripdata_2019[(green_tripdata_2019['lpep_pickup_datetime']>='2019-01-01 00:00:00') & 
(green_tripdata_2019['lpep_pickup_datetime']<'2019-01-02 00:00:00')]

# %%
green_tripdata_2019_enero[(green_tripdata_2019_enero['passenger_count']==2)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 11            2  2019-01-01 00:13:48   2019-01-01 00:21:00                  N
# 32            2  2019-01-01 00:40:23   2019-01-01 00:56:12                  N
# ...         ...                  ...                   ...                ...
# 14971         2  2019-01-01 23:33:40   2019-01-01 23:56:47                  N
# 14996         2  2019-01-01 23:10:16   2019-01-01 23:18:13                  N
# 14997         2  2019-01-01 23:34:15   2019-01-01 23:44:05                  N
# 15029         1  2019-01-01 23:08:14   2019-01-01 23:12:59                  N
# 15032         1  2019-01-01 23:42:48   2019-01-01 23:47:44                  N
#
# ...

# %%
green_tripdata_2019_enero[(green_tripdata_2019_enero['passenger_count']==3)]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 31            2  2019-01-01 00:08:07   2019-01-01 00:18:36                  N
# 40            2  2019-01-01 00:31:28   2019-01-01 00:57:27                  N
# 67            2  2019-01-01 00:39:51   2019-01-01 00:43:05                  N
# 149           2  2019-01-01 00:35:40   2019-01-01 01:20:13                  N
# 185           2  2019-01-01 00:09:09   2019-01-01 01:04:26                  N
# ...         ...                  ...                   ...                ...
# 14666         1  2019-01-01 22:15:36   2019-01-01 22:28:07                  N
# 14753         1  2019-01-01 23:46:40   2019-01-01 23:53:04                  N
# 14830         2  2019-01-01 23:20:47   2019-01-01 23:28:04                  N
# 14959         2  2019-01-01 23:16:50   2019-01-01 23:24:38                  N
# 14970         2  2019-01-01 23:34:57   2019-01-01 23:45:51                  N
#
# ...

# %%
green_tripdata_2019[(green_tripdata_2019['lpep_pickup_datetime']>='2019-01-15 00:00:00') & 
(green_tripdata_2019['lpep_pickup_datetime']<'2019-01-16 00:00:00')]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 272684         2  2019-01-15 15:33:43   2019-01-15 15:33:50
# 275421         2  2019-01-15 16:50:12   2019-01-15 17:23:03
# 276753         2  2019-01-15 17:44:00   2019-01-15 18:03:10
# 278806         2  2019-01-15 20:02:24   2019-01-15 20:17:52
# 279998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# ...          ...                  ...                   ...
# 301223         2  2019-01-15 22:29:47   2019-01-15 22:39:48
# 301247         2  2019-01-15 23:59:16   2019-01-16 00:05:11
# 301258         2  2019-01-15 22:56:18   2019-01-15 23:43:35
# 301411         2  2019-01-15 22:18:09   2019-01-15 22:25:53
# 301517         2  2019-01-15 21:52:54   2019-01-15 21:55:14
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 272684                  N           5           195           195
# 275421                  N           1           195            17
# ...

# %%
green_tripdata_2019
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
df.lpep_pickup_datetime=pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime=pd.to_datetime(df.lpep_dropoff_datetime)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df,name='green_tripdata_2019-01',con=engine))
# Out:
# CREATE TABLE "green_tripdata_2019-01" (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter=pd.read_csv('green_tripdata_2019-01.csv',iterator=True,chunksize=100000)

# %%
df=next(df_iter)

# %%
df.lpep_pickup_datetime=pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime=pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head(0).to_sql(name='green_tripdata_2019-01',con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_tripdata_2019-01',con=engine,if_exists='append')
# Out:
# CPU times: total: 2.91 s
# Wall time: 8.62 s
# 1000

# %%
from time import time

# %%
while True:
    t_start =time()
    df = next(df_iter)
    df.lpep_pickup_datetime=pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime=pd.to_datetime(df.lpep_dropoff_datetime)
    df.to_sql(name='green_tripdata_2019-01',con=engine,if_exists='append')
    t_end=time()
    print('inserted another chock..., took %.3f second' %(t_end-t_start))
# Out:
# inserted another chock..., took 9.120 second
# inserted another chock..., took 9.349 second
# inserted another chock..., took 9.440 second
# inserted another chock..., took 9.433 second
# inserted another chock..., took 9.497 second
# inserted another chock..., took 3.122 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[52], line 3
#       1 while True:
#       2     t_start =time()
# ----> 3     df = next(df_iter)
#       4     df.lpep_pickup_datetime=pd.to_datetime(df.lpep_pickup_datetime)
#       5     df.lpep_dropoff_datetime=pd.to_datetime(df.lpep_dropoff_datetime)
#
# File c:\Users\diego\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1698, in TextFileReader.__next__(self)
#    1696 def __next__(self) -> DataFrame:
#    1697     try:
# -> 1698         return self.get_chunk()
#    1699     except StopIteration:
# ...
